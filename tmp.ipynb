# %%
import scipy.io
import plotly.graph_objects as go

# %%
mat = scipy.io.loadmat('./data/output/14441946-10-24_007_output.mat')
mat['ecg'].shape
# Out:
# (12, 5000)

# %%
go.Figure(go.Line(y=mat['ecg'][0,::4])).show()
# Out:
# <div>                            <div id="ebd35f8c-ab83-400a-a414-e3181f4e1e8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ebd35f8c-ab83-400a-a414-e3181f4e1e8b")) {                    Plotly.newPlot(                        "ebd35f8c-ab83-400a-a414-e3181f4e1e8b",                        [{"y":[-47,-50,-47,-41,-34,-37,-48,-46,-34,-36,-51,-57,-49,-39,-40,-40,-29,-25,-35,-35,-23,-28,-47,-51,-37,-30,-33,-37,-37,-39,-42,-46,-43,-34,-37,-44,-34,-21,-18,-12,-14,-28,-29,-19,-13,-14,-19,-21,-30,-51,-60,-45,-33,-42,-50,-44,-50,-87,-123,-87,94,375,519,370,81,-92,-100,-62,-57,-56,-41,-38,-42,-39,-37,-40,-44,-49,-53,-52,-53,-54,-49,-31,-17,-18,-25,-22,-12,-8,-11,-3,26,59,57,28,29,64,70,36,14,14,10,-4,-23,-42,-47,-40,-34,-32,-28,-30,-39,-45,-48,-56,-65,-64,-55
# ...

# %%
import pandas as pd

df =  pd.read_csv('./data/filtered_output_csv.csv',sep=';')
len(df.iloc[0]['Text'].strip())
# Out:
# 0
